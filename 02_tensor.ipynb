# %%
import torch
print(torch.__version__)
# Out:
# 2.12.0+cpu

# %%
if torch.cuda.is_available():
    print("GPU is available")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available, using CPU")
# Out:
# GPU is not available, using CPU

# %%
a = torch.zeros(2,2)
print(a)
# Out:
# tensor([[0., 0.],
#         [0., 0.]])

# %%
a = torch.tensor(a, dtype=torch.float16)
print(a)
# Out:
# tensor([[0.7920, 0.4153, 0.9556],
#         [0.5723, 0.6035, 0.5273]], dtype=torch.float16)
# C:\Users\Ayub\AppData\Local\Temp\ipykernel_15544\3984163351.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   a = torch.tensor(a, dtype=torch.float16)

# %% [markdown]
# mathametical operations

# %% [markdown]
# 1. scalar operations

# %%
x = torch.rand(2,2)
x
# Out:
# tensor([[0.2626, 0.0357],
#         [0.0626, 0.8930]])

# %% [markdown]
# Addition

# %%
x + 3
# Out:
# tensor([[3.2626, 3.0357],
#         [3.0626, 3.8930]])

# %% [markdown]
# Substraction

# %%
x - 2
# Out:
# tensor([[-1.7374, -1.9643],
#         [-1.9374, -1.1070]])

# %% [markdown]
# Mod

# %%
((x*100)//3)%2
# Out:
# tensor([[0., 1.],
#         [0., 1.]])

# %% [markdown]
# Power

# %%
x**2
# Out:
# tensor([[0.0689, 0.0013],
#         [0.0039, 0.7975]])

# %% [markdown]
# Inplace operation
#
# use for memory saving

# %%
m = torch.rand(2,3)
n = torch.rand(2,3)
print(m)
print(n)
# Out:
# tensor([[0.3692, 0.3741, 0.9593],
#         [0.1728, 0.4908, 0.6941]])
# tensor([[0.8426, 0.6836, 0.5635],
#         [0.7165, 0.8644, 0.7741]])

# %%
m + n
# Out:
# tensor([[1.2117, 1.0577, 1.5228],
#         [0.8893, 1.3552, 1.4682]])

# %% [markdown]
# while this will create a whole new slot in memory we can use inplace opretor to make changes in the same memory slot of tensor

# %%
m.add_(n)
# Out:
# tensor([[1.2117, 1.0577, 1.5228],
#         [0.8893, 1.3552, 1.4682]])

# %%
m
# Out:
# tensor([[1.2117, 1.0577, 1.5228],
#         [0.8893, 1.3552, 1.4682]])

# %%
m.relu_()
# Out:
# tensor([[1.2117, 1.0577, 1.5228],
#         [0.8893, 1.3552, 1.4682]])

# %% [markdown]
# copying a tensor

# %%
a = torch.rand(2,3)
print(a)
# Out:
# tensor([[0.8680, 0.6304, 0.8117],
#         [0.2857, 0.5717, 0.9864]])

# %%
b = a.clone()

# %%
a
# Out:
# tensor([[0.8680, 0.6304, 0.8117],
#         [0.2857, 0.5717, 0.9864]])

# %%
b
# Out:
# tensor([[0.8680, 0.6304, 0.8117],
#         [0.2857, 0.5717, 0.9864]])

# %%
a[0][0] = 0

# %%
a
# Out:
# tensor([[0.0000, 0.6304, 0.8117],
#         [0.2857, 0.5717, 0.9864]])

# %%
b
# Out:
# tensor([[0.8680, 0.6304, 0.8117],
#         [0.2857, 0.5717, 0.9864]])

# %%
id(a)
# Out:
# 2437739156720

# %%
id(b)
# Out:
# 2437738737536

# %% [markdown]
# Tensor operations on GPU

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# use google colab or jupytrr notebook if nividia is not available
