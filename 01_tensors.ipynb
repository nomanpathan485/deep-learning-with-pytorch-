# %%
import torch

print(torch.__version__)
# Out:
# 2.12.0+cpu

# %%
x = torch.tensor([1,2,3])
print(x)
# Out:
# tensor([1, 2, 3])

# %%
x = torch.tensor(5)
print(x)
# Out:
# tensor(5)

# %% [markdown]
# 0D Tensor (Scalar)

# %% [markdown]
# 1D Tensor (Vector)

# %%
x = torch.tensor([1, 2, 3])

print(x)
# Out:
# tensor([1, 2, 3])

# %% [markdown]
# 2D Tensor (Matrix)

# %%
x = torch.tensor([
    [1,2],
    [3,4]
])
print(x)
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %% [markdown]
# 3D dimension

# %%
x = torch.tensor([
    [[1,2],[3,4]],
    [[5,6],[7,8]]
])

print(x)
# Out:
# tensor([[[1, 2],
#          [3, 4]],
#
#         [[5, 6],
#          [7, 8]]])

# %% [markdown]
# More dimensions = More information

# %% [markdown]
# shape

# %%
x = torch.tensor([
    [1,2],
    [3,4]
])

print(x.shape)
# Out:
# torch.Size([2, 2])

# %% [markdown]
# 2 rows
# 2 columns

# %% [markdown]
# Dimension

# %%
print(x.ndim)
# Out:
# 2

# %% [markdown]
# Data Type

# %%
print(x.dtype)
# Out:
# torch.int64

# %%
import torch

x = torch.tensor([
    [1,2,3],
    [4,5,6]
])

print(x)
print(x.shape)
print(x.ndim)
print(x.dtype)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])
# torch.Size([2, 3])
# 2
# torch.int64
